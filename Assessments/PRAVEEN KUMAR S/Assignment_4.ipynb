# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
out = pd.read_csv(r"D:\project\Assessments\Mall_Customers.csv")

# %% [markdown]
# # Univariant Analysis

# %%
sns.displot(['Spending Score (1-100)'])

# %%
sns.histplot(out['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %% [markdown]
# # Bivariate Analaysis

# %%
sns.lineplot(out['Age'], out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.barplot(out['Age'], out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
plt.figure(figsize=(45,50))
sns.barplot(out['Age'], out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.scatterplot(values = out, a = 'Age', b = 'Annual Income (k$)')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.scatterplot(out['Annual Income (k$)'], out['Spending Score (1-100)'], hue = out["Age"])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
sns.pairplot(out)

# %% [markdown]
# # Descriptive Statistics

# %%
out.mean(numeric_only = True)
# Out:
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
out.median(numeric_only = True)
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
out['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
out['Annual Income (k$)'].unique()
# Out:
# array([ 15,  16,  17,  18,  19,  20,  21,  23,  24,  25,  28,  29,  30,
#         33,  34,  37,  38,  39,  40,  42,  43,  44,  46,  47,  48,  49,
#         50,  54,  57,  58,  59,  60,  61,  62,  63,  64,  65,  67,  69,
#         70,  71,  72,  73,  74,  75,  76,  77,  78,  79,  81,  85,  86,
#         87,  88,  93,  97,  98,  99, 101, 103, 113, 120, 126, 137],
#       dtype=int64)

# %%
out.std(numeric_only=True)
# Out:
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
out.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
out.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
out.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
sns.boxplot(out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
k = out.quantile([0.75,0.25])

# %%
k
# Out:
#       CustomerID    Age  Annual Income (k$)  Spending Score (1-100)
# 0.75      150.25  49.00                78.0                   73.00
# 0.25       50.75  28.75                41.5                   34.75

# %%
iqr =  k.iloc[0] - k.iloc[1]

# %%
iqr
# Out:
# CustomerID                99.50
# Age                       20.25
# Annual Income (k$)        36.50
# Spending Score (1-100)    38.25
# dtype: float64

# %%
v = k.iloc[0] + (1.5*iqr)

# %%
v
# Out:
# CustomerID                299.500
# Age                        79.375
# Annual Income (k$)        132.750
# Spending Score (1-100)    130.375
# dtype: float64

# %%
x = k.iloc[1] - (1.5*iqr)

# %%
x
# Out:
# CustomerID               -98.500
# Age                       -1.625
# Annual Income (k$)       -13.250
# Spending Score (1-100)   -22.625
# dtype: float64

# %%
arr['Annual Income (k$)'] = np.where(np.logical_or(out['Annual Income (k$)']>132.75,out['Annual Income (k$)']<-13.250), 61.5,out['Annual Income (k$)'])

# %%
sns.boxplot(out['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
out['Gender'] = le.fit_transform(out['Gender'])

# %%
out.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
x_scaled = min_max.fit_transform(out)

# %%
x_scaled
# Out:
# array([[0.        , 1.        , 0.01923077, 0.        , 0.3877551 ],
#        [0.00502513, 1.        , 0.05769231, 0.        , 0.81632653],
#        [0.01005025, 0.        , 0.03846154, 0.00819672, 0.05102041],
#        [0.01507538, 0.        , 0.09615385, 0.00819672, 0.7755102 ],
#        [0.0201005 , 0.        , 0.25      , 0.01639344, 0.39795918],
#        [0.02512563, 0.        , 0.07692308, 0.01639344, 0.76530612],
#        [0.03015075, 0.        , 0.32692308, 0.02459016, 0.05102041],
#        [0.03517588, 0.        , 0.09615385, 0.02459016, 0.94897959],
#        [0.04020101, 1.        , 0.88461538, 0.03278689, 0.02040816],
#        [0.04522613, 0.        , 0.23076923, 0.03278689, 0.7244898 ],
#        [0.05025126, 1.        , 0.94230769, 0.03278689, 0.13265306],
#        [0.05527638, 0.        , 0.32692308, 0.03278689, 1.        ],
#        [0.06030151, 0.        , 0.76923077, 0.04098361, 0.14285714],
#        [0.06532663, 0.        , 0.11538462, 0.04098361, 0.7755102 ],
# ...

# %%
from sklearn.cluster import KMeans
KM=KMeans()
cluster = KM.fit_predict(x_scaled)

# %%
cluster
# Out:
# array([2, 2, 0, 0, 0, 0, 6, 0, 4, 0, 4, 0, 6, 0, 4, 2, 0, 2, 4, 0, 2, 2,
#        6, 2, 6, 2, 6, 2, 6, 0, 4, 0, 4, 2, 6, 0, 6, 0, 6, 0, 6, 2, 4, 0,
#        6, 0, 6, 0, 0, 0, 6, 2, 0, 4, 6, 4, 6, 4, 0, 4, 4, 2, 6, 6, 4, 2,
#        6, 6, 2, 0, 4, 6, 6, 6, 4, 2, 6, 2, 0, 6, 4, 2, 4, 6, 0, 4, 6, 0,
#        0, 6, 6, 2, 4, 6, 0, 2, 6, 0, 4, 2, 0, 6, 4, 2, 4, 0, 6, 4, 4, 4,
#        4, 0, 7, 2, 0, 0, 6, 6, 6, 6, 5, 7, 3, 5, 7, 3, 1, 5, 1, 5, 1, 5,
#        7, 3, 1, 3, 7, 5, 1, 3, 7, 5, 7, 3, 1, 5, 1, 3, 7, 5, 1, 5, 7, 3,
#        7, 3, 1, 3, 1, 3, 7, 3, 1, 3, 1, 3, 1, 3, 7, 5, 1, 5, 1, 5, 7, 3,
#        1, 5, 1, 5, 7, 3, 1, 3, 7, 5, 7, 5, 7, 3, 7, 3, 1, 3, 7, 3, 7, 5,
#        1, 5])

# %%
val = out.columns

# %%
val
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
d1 = pd.DataFrame(x_scaled, columns = val)

# %%
d1
# Out:
#      CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0      0.000000     1.0  0.019231            0.000000                0.387755
# 1      0.005025     1.0  0.057692            0.000000                0.816327
# 2      0.010050     0.0  0.038462            0.008197                0.051020
# 3      0.015075     0.0  0.096154            0.008197                0.775510
# 4      0.020101     0.0  0.250000            0.016393                0.397959
# ..          ...     ...       ...                 ...                     ...
# 195    0.979899     0.0  0.326923            0.860656                0.795918
# 196    0.984925     0.0  0.519231            0.909836                0.275510
# 197    0.989950     1.0  0.269231            0.909836                0.744898
# 198    0.994975     1.0  0.269231            1.000000                0.173469
# 199    1.000000     1.0  0.230769            1.000000                0.836735
#
# [200 rows x 5 columns]

# %%
d1['Cluster_value'] = pd.Series(cluster)

# %%
d1.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.008197                0.051020
# 3    0.015075     0.0  0.096154            0.008197                0.775510
# 4    0.020101     0.0  0.250000            0.016393                0.397959
#
#    Cluster_value
# 0              2
# 1              2
# 2              0
# 3              0
# 4              0

# %% [markdown]
# # Split the data in X and Y

# %%
b = d1['Cluster_value']
d1 = d1.drop(['CustomerID','Cluster_value'], axis = 1)
a = d1
a
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0       1.0  0.019231            0.000000                0.387755
# 1       1.0  0.057692            0.000000                0.816327
# 2       0.0  0.038462            0.008197                0.051020
# 3       0.0  0.096154            0.008197                0.775510
# 4       0.0  0.250000            0.016393                0.397959
# ..      ...       ...                 ...                     ...
# 195     0.0  0.326923            0.860656                0.795918
# 196     0.0  0.519231            0.909836                0.275510
# 197     1.0  0.269231            0.909836                0.744898
# 198     1.0  0.269231            1.000000                0.173469
# 199     1.0  0.230769            1.000000                0.836735
#
# [200 rows x 4 columns]

# %%
b
# Out:
# 0      2
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 195    3
# 196    7
# 197    5
# 198    1
# 199    5
# Name: Cluster_value, Length: 200, dtype: int32

# %% [markdown]
# # Split x and y into Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, b, test_size = 0.3, random_state = 0)

# %%
x_train
# Out:
# array([[0.65829146, 1.        , 0.40384615, 0.45901639, 0.75510204],
#        [0.48241206, 0.        , 0.55769231, 0.36885246, 0.46938776],
#        [0.90954774, 0.        , 0.26923077, 0.67213115, 0.86734694],
#        [0.09547739, 0.        , 0.32692308, 0.06557377, 0.98979592],
#        [0.76884422, 0.        , 0.38461538, 0.51639344, 0.76530612],
#        [0.46231156, 1.        , 0.57692308, 0.36885246, 0.48979592],
#        [0.27135678, 0.        , 0.61538462, 0.2295082 , 0.44897959],
#        [0.81909548, 0.        , 0.25      , 0.54098361, 0.93877551],
#        [0.25628141, 1.        , 0.28846154, 0.22131148, 0.60204082],
#        [0.4321608 , 0.        , 0.71153846, 0.3442623 , 0.58163265],
#        [0.69849246, 0.        , 0.32692308, 0.48360656, 0.7244898 ],
#        [0.45226131, 0.        , 0.96153846, 0.36065574, 0.55102041],
#        [0.68844221, 1.        , 0.26923077, 0.47540984, 0.73469388],
#        [0.50753769, 0.        , 0.59615385, 0.3852459 , 0.47959184],
# ...

# %%
x_train.shape
# Out:
# (140, 5)

# %%
x_test
# Out:
# array([[0.09045226, 1.        , 0.65384615, 0.06557377, 0.28571429],
#        [0.85427136, 1.        , 0.42307692, 0.59016393, 0.12244898],
#        [0.53768844, 1.        , 0.69230769, 0.39344262, 0.45918367],
#        [0.49246231, 1.        , 0.57692308, 0.37704918, 0.41836735],
#        [0.88944724, 1.        , 0.17307692, 0.59836066, 0.69387755],
#        [0.91457286, 1.        , 0.53846154, 0.68032787, 0.14285714],
#        [0.02512563, 0.        , 0.07692308, 0.01639344, 0.76530612],
#        [0.73366834, 1.        , 0.57692308, 0.50819672, 0.35714286],
#        [0.06030151, 0.        , 0.76923077, 0.04098361, 0.14285714],
#        [0.7638191 , 0.        , 0.5       , 0.51639344, 0.19387755],
#        [0.30653266, 1.        , 0.01923077, 0.25409836, 0.55102041],
#        [0.6281407 , 0.        , 0.25      , 0.45081967, 0.7755102 ],
#        [0.90452261, 0.        , 0.36538462, 0.67213115, 0.31632653],
#        [0.77386935, 0.        , 0.55769231, 0.51639344, 0.15306122],
# ...

# %%
x_test.shape
# Out:
# (60, 5)

# %%
y_train
# Out:
# 131    5
# 96     6
# 181    3
# 19     0
# 153    3
#       ..
# 67     6
# 192    1
# 117    6
# 47     0
# 172    1
# Name: Cluster_value, Length: 140, dtype: int32

# %%
y_test
# Out:
# 18     4
# 170    1
# 107    4
# 98     4
# 177    5
# 182    1
# 5      0
# 146    1
# 12     6
# 152    7
# 61     2
# 125    3
# 180    7
# 154    7
# 80     4
# 7      0
# 33     2
# 130    1
# 37     0
# 74     4
# 183    3
# 145    5
# 45     0
# 159    3
# 60     4
# 123    5
# 179    5
# 185    5
# 122    3
# 44     6
# 16     0
# 55     4
# 150    1
# 111    0
# 22     6
# 189    3
# 129    5
# 4      0
# 83     6
# 106    6
# 134    1
# 66     6
# 26     6
# 113    2
# 168    7
# 63     6
# 8      4
# 75     2
# 118    6
# 143    3
# 71     6
# 124    7
# 184    7
# 97     0
# 149    5
# 24     6
# 30     4
# 160    7
# 40     6
# 56     6
# Name: Cluster_value, dtype: int32

# %% [markdown]
# # Multi inear regression model

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = mlr.predict(x_test)

# %%
pred
# Out:
# array([3.23839707, 3.54826201, 4.22457009, 3.64890162, 2.41202816,
#        4.25881166, 1.32379956, 4.01971892, 4.56743035, 4.569487  ,
#        0.79093359, 3.20502051, 4.29853093, 4.83990756, 4.27659381,
#        1.41893461, 0.41437884, 3.81897945, 2.35576346, 4.43552153,
#        3.58631706, 2.23145267, 1.93111207, 3.33419317, 5.23597767,
#        3.0176368 , 3.17108827, 2.83143876, 3.97982121, 4.13347902,
#        2.57377288, 3.18302475, 3.62218152, 2.03432189, 3.62679516,
#        4.28626313, 2.9869158 , 2.12981641, 4.18682945, 6.12164386,
#        1.50621374, 3.78661738, 3.5751967 , 1.20353599, 4.03995851,
#        4.71722951, 4.21683749, 1.55529371, 4.90955759, 3.42314828,
#        4.16985867, 2.53611551, 4.68257666, 2.65088501, 2.7854556 ,
#        4.36619203, 4.08607887, 5.6443499 , 5.49854167, 4.39881979])

# %%
y_test
# Out:
# 18     4
# 170    1
# 107    4
# 98     4
# 177    5
# 182    1
# 5      0
# 146    1
# 12     6
# 152    7
# 61     2
# 125    3
# 180    7
# 154    7
# 80     4
# 7      0
# 33     2
# 130    1
# 37     0
# 74     4
# 183    3
# 145    5
# 45     0
# 159    3
# 60     4
# 123    5
# 179    5
# 185    5
# 122    3
# 44     6
# 16     0
# 55     4
# 150    1
# 111    0
# 22     6
# 189    3
# 129    5
# 4      0
# 83     6
# 106    6
# 134    1
# 66     6
# 26     6
# 113    2
# 168    7
# 63     6
# 8      4
# 75     2
# 118    6
# 143    3
# 71     6
# 124    7
# 184    7
# 97     0
# 149    5
# 24     6
# 30     4
# 160    7
# 40     6
# 56     6
# Name: Cluster_value, dtype: int32

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
mean= mean_squared_error(y_test,pred)
mean
# Out:
# 3.567206898945775

# %%
rmse = np.sqrt(mean)
rmse
# Out:
# 1.8887050852226175

# %%
r2_score(y_test,pred)
# Out:
# 0.34008505466573546
