# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
var = pd.read_csv(r"D:\project\Assessments\Mall_Customers.csv")

# %% [markdown]
# # Univariant Analysis

# %%
sns.displot(var['Spending Score (1-100)'])

# %%
sns.histplot(var['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %% [markdown]
# # Bivariate Analaysis

# %%
sns.lineplot(var['Age'], var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.barplot(var['Age'], var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
plt.figure(figsize=(45,50))
sns.barplot(var['Age'], var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.scatterplot(values = var, a = 'Age', b = 'Annual Income (k$)')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.scatterplot(var['Annual Income (k$)'], var['Spending Score (1-100)'], hue = var["Age"])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
sns.pairplot(var)

# %% [markdown]
# # Descriptive Statistics

# %%
var.mean(numeric_only = True)
# Out:
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
var.median(numeric_only = True)
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
var['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
var['Annual Income (k$)'].unique()
# Out:
# array([ 15,  16,  17,  18,  19,  20,  21,  23,  24,  25,  28,  29,  30,
#         33,  34,  37,  38,  39,  40,  42,  43,  44,  46,  47,  48,  49,
#         50,  54,  57,  58,  59,  60,  61,  62,  63,  64,  65,  67,  69,
#         70,  71,  72,  73,  74,  75,  76,  77,  78,  79,  81,  85,  86,
#         87,  88,  93,  97,  98,  99, 101, 103, 113, 120, 126, 137],
#       dtype=int64)

# %%
var.std(numeric_only=True)
# Out:
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
var.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
var.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
var.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
sns.boxplot(var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
k = var.quantile([0.75,0.25])

# %%
k
# Out:
#       CustomerID    Age  Annual Income (k$)  Spending Score (1-100)
# 0.75      150.25  49.00                78.0                   73.00
# 0.25       50.75  28.75                41.5                   34.75

# %%
iqr =  k.iloc[0] - k.iloc[1]

# %%
iqr
# Out:
# CustomerID                99.50
# Age                       20.25
# Annual Income (k$)        36.50
# Spending Score (1-100)    38.25
# dtype: float64

# %%
v = k.iloc[0] + (1.5*iqr)

# %%
v
# Out:
# CustomerID                299.500
# Age                        79.375
# Annual Income (k$)        132.750
# Spending Score (1-100)    130.375
# dtype: float64

# %%
x = r.iloc[1] - (1.5*iqr)

# %%
x
# Out:
# CustomerID               -98.500
# Age                       -1.625
# Annual Income (k$)       -13.250
# Spending Score (1-100)   -22.625
# dtype: float64

# %%
var['Annual Income (k$)'] = np.where(np.logical_or(var['Annual Income (k$)']>132.75,var['Annual Income (k$)']<-13.250), 61.5,var['Annual Income (k$)'])

# %%
sns.boxplot(var['Annual Income (k$)'])
# Out:
# C:\Users\vishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
var['Gender'] = le.fit_transform(var['Gender'])

# %%
var.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                15.0                      39
# 1           2       1   21                15.0                      81
# 2           3       0   20                16.0                       6
# 3           4       0   23                16.0                      77
# 4           5       0   31                17.0                      40

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
x_scaled = min_max.fit_transform(var)

# %%
x_scaled
# Out:
# array([[0.        , 1.        , 0.01923077, 0.        , 0.3877551 ],
#        [0.00502513, 1.        , 0.05769231, 0.        , 0.81632653],
#        [0.01005025, 0.        , 0.03846154, 0.00900901, 0.05102041],
#        [0.01507538, 0.        , 0.09615385, 0.00900901, 0.7755102 ],
#        [0.0201005 , 0.        , 0.25      , 0.01801802, 0.39795918],
#        [0.02512563, 0.        , 0.07692308, 0.01801802, 0.76530612],
#        [0.03015075, 0.        , 0.32692308, 0.02702703, 0.05102041],
#        [0.03517588, 0.        , 0.09615385, 0.02702703, 0.94897959],
#        [0.04020101, 1.        , 0.88461538, 0.03603604, 0.02040816],
#        [0.04522613, 0.        , 0.23076923, 0.03603604, 0.7244898 ],
#        [0.05025126, 1.        , 0.94230769, 0.03603604, 0.13265306],
#        [0.05527638, 0.        , 0.32692308, 0.03603604, 1.        ],
#        [0.06030151, 0.        , 0.76923077, 0.04504505, 0.14285714],
#        [0.06532663, 0.        , 0.11538462, 0.04504505, 0.7755102 ],
# ...

# %%
from sklearn.cluster import KMeans
KM=KMeans()
cluster = KM.fit_predict(x_scaled)

# %%
cluster
# Out:
# array([2, 2, 0, 0, 0, 0, 3, 0, 5, 0, 5, 0, 3, 0, 2, 2, 0, 2, 5, 0, 2, 2,
#        3, 2, 3, 2, 3, 2, 3, 0, 5, 0, 5, 2, 3, 0, 3, 0, 3, 0, 3, 2, 5, 0,
#        3, 0, 3, 0, 0, 0, 3, 2, 0, 5, 3, 5, 3, 5, 0, 5, 5, 2, 3, 3, 5, 2,
#        3, 3, 2, 0, 5, 3, 3, 3, 5, 2, 3, 2, 0, 3, 5, 2, 5, 3, 0, 5, 3, 0,
#        0, 3, 3, 2, 5, 3, 0, 2, 3, 0, 5, 2, 0, 3, 5, 2, 5, 0, 3, 5, 5, 5,
#        5, 0, 3, 2, 0, 0, 3, 3, 3, 3, 6, 4, 7, 6, 4, 7, 1, 6, 1, 6, 1, 6,
#        4, 7, 1, 7, 4, 6, 1, 7, 4, 6, 4, 7, 1, 6, 1, 7, 4, 6, 1, 6, 4, 7,
#        4, 7, 1, 7, 1, 7, 4, 7, 1, 7, 1, 7, 1, 7, 4, 6, 1, 6, 1, 6, 4, 7,
#        1, 6, 1, 6, 4, 7, 1, 7, 4, 6, 4, 6, 4, 7, 4, 7, 1, 7, 4, 7, 4, 6,
#        1, 6])

# %%
val = var.columns

# %%
val
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
d1 = pd.DataFrame(x_scaled, columns = value)

# %%
d1
# Out:
#      CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0      0.000000     1.0  0.019231            0.000000                0.387755
# 1      0.005025     1.0  0.057692            0.000000                0.816327
# 2      0.010050     0.0  0.038462            0.009009                0.051020
# 3      0.015075     0.0  0.096154            0.009009                0.775510
# 4      0.020101     0.0  0.250000            0.018018                0.397959
# ..          ...     ...       ...                 ...                     ...
# 195    0.979899     0.0  0.326923            0.945946                0.795918
# 196    0.984925     0.0  0.519231            1.000000                0.275510
# 197    0.989950     1.0  0.269231            1.000000                0.744898
# 198    0.994975     1.0  0.269231            0.418919                0.173469
# 199    1.000000     1.0  0.230769            0.418919                0.836735
#
# [200 rows x 5 columns]

# %%
d1['Cluster_value'] = pd.Series(cluster)

# %%
d1.head()
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0    0.000000     1.0  0.019231            0.000000                0.387755
# 1    0.005025     1.0  0.057692            0.000000                0.816327
# 2    0.010050     0.0  0.038462            0.009009                0.051020
# 3    0.015075     0.0  0.096154            0.009009                0.775510
# 4    0.020101     0.0  0.250000            0.018018                0.397959
#
#    Cluster_value
# 0              2
# 1              2
# 2              0
# 3              0
# 4              0

# %% [markdown]
# # Split the data in X and Y

# %%
b = d1['Cluster_value']
d1 = d1.drop(['CustomerID','Cluster_value'], axis = 1)
a = d1
a
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0       1.0  0.019231            0.000000                0.387755
# 1       1.0  0.057692            0.000000                0.816327
# 2       0.0  0.038462            0.009009                0.051020
# 3       0.0  0.096154            0.009009                0.775510
# 4       0.0  0.250000            0.018018                0.397959
# ..      ...       ...                 ...                     ...
# 195     0.0  0.326923            0.945946                0.795918
# 196     0.0  0.519231            1.000000                0.275510
# 197     1.0  0.269231            1.000000                0.744898
# 198     1.0  0.269231            0.418919                0.173469
# 199     1.0  0.230769            0.418919                0.836735
#
# [200 rows x 4 columns]

# %%
b
# Out:
# 0      2
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 195    7
# 196    4
# 197    6
# 198    1
# 199    6
# Name: Cluster_value, Length: 200, dtype: int32

# %% [markdown]
# # Split x and y into Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, b, test_size = 0.3, random_state = 0)

# %%
x_train
# Out:
# array([[0.65829146, 1.        , 0.40384615, 0.5045045 , 0.75510204],
#        [0.48241206, 0.        , 0.55769231, 0.40540541, 0.46938776],
#        [0.90954774, 0.        , 0.26923077, 0.73873874, 0.86734694],
#        [0.09547739, 0.        , 0.32692308, 0.07207207, 0.98979592],
#        [0.76884422, 0.        , 0.38461538, 0.56756757, 0.76530612],
#        [0.46231156, 1.        , 0.57692308, 0.40540541, 0.48979592],
#        [0.27135678, 0.        , 0.61538462, 0.25225225, 0.44897959],
#        [0.81909548, 0.        , 0.25      , 0.59459459, 0.93877551],
#        [0.25628141, 1.        , 0.28846154, 0.24324324, 0.60204082],
#        [0.4321608 , 0.        , 0.71153846, 0.37837838, 0.58163265],
#        [0.69849246, 0.        , 0.32692308, 0.53153153, 0.7244898 ],
#        [0.45226131, 0.        , 0.96153846, 0.3963964 , 0.55102041],
#        [0.68844221, 1.        , 0.26923077, 0.52252252, 0.73469388],
#        [0.50753769, 0.        , 0.59615385, 0.42342342, 0.47959184],
# ...

# %%
x_train.shape
# Out:
# (140, 5)

# %%
x_test
# Out:
# array([[0.09045226, 1.        , 0.65384615, 0.07207207, 0.28571429],
#        [0.85427136, 1.        , 0.42307692, 0.64864865, 0.12244898],
#        [0.53768844, 1.        , 0.69230769, 0.43243243, 0.45918367],
#        [0.49246231, 1.        , 0.57692308, 0.41441441, 0.41836735],
#        [0.88944724, 1.        , 0.17307692, 0.65765766, 0.69387755],
#        [0.91457286, 1.        , 0.53846154, 0.74774775, 0.14285714],
#        [0.02512563, 0.        , 0.07692308, 0.01801802, 0.76530612],
#        [0.73366834, 1.        , 0.57692308, 0.55855856, 0.35714286],
#        [0.06030151, 0.        , 0.76923077, 0.04504505, 0.14285714],
#        [0.7638191 , 0.        , 0.5       , 0.56756757, 0.19387755],
#        [0.30653266, 1.        , 0.01923077, 0.27927928, 0.55102041],
#        [0.6281407 , 0.        , 0.25      , 0.4954955 , 0.7755102 ],
#        [0.90452261, 0.        , 0.36538462, 0.73873874, 0.31632653],
#        [0.77386935, 0.        , 0.55769231, 0.56756757, 0.15306122],
# ...

# %%
x_test.shape
# Out:
# (60, 5)

# %%
y_train
# Out:
# 131    6
# 96     3
# 181    7
# 19     0
# 153    7
#       ..
# 67     3
# 192    1
# 117    3
# 47     0
# 172    1
# Name: Cluster_value, Length: 140, dtype: int32

# %%
y_test
# Out:
# 18     5
# 170    1
# 107    5
# 98     5
# 177    6
# 182    1
# 5      0
# 146    1
# 12     3
# 152    4
# 61     2
# 125    7
# 180    4
# 154    4
# 80     5
# 7      0
# 33     2
# 130    1
# 37     0
# 74     5
# 183    7
# 145    6
# 45     0
# 159    7
# 60     5
# 123    6
# 179    6
# 185    6
# 122    7
# 44     3
# 16     0
# 55     5
# 150    1
# 111    0
# 22     3
# 189    7
# 129    6
# 4      0
# 83     3
# 106    3
# 134    1
# 66     3
# 26     3
# 113    2
# 168    4
# 63     3
# 8      5
# 75     2
# 118    3
# 143    7
# 71     3
# 124    4
# 184    4
# 97     0
# 149    6
# 24     3
# 30     5
# 160    4
# 40     3
# 56     3
# Name: Cluster_value, dtype: int32

# %% [markdown]
# # Multi inear regression model

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = mlr.predict(x_test)

# %%
pred
# Out:
# array([ 1.66124774,  3.21664181,  4.27549127,  3.55136597,  4.90780387,
#         3.93663515,  1.11500393,  4.23111451,  0.9433296 ,  3.02640698,
#         1.53372955,  4.1042742 ,  3.66542987,  3.08379565,  4.15295938,
#         1.98493591,  2.48981994,  2.70422328,  2.13697582,  3.9984575 ,
#         5.60013615,  5.53921319,  1.57751651,  4.52345649,  4.79848902,
#         5.55216503,  6.3615771 ,  6.47012974,  3.80865208,  1.57202108,
#         0.41046767,  2.59707056,  3.18133137,  2.08299699, -0.04546857,
#         6.04256704,  4.92421183,  0.13539399,  2.82823407,  4.8064979 ,
#         0.89803737,  2.56092429,  1.12334764,  2.16555   ,  3.13823018,
#         3.58469027,  1.11990994,  2.21813922,  3.78907991,  4.94435513,
#         2.56998038,  1.53343789,  4.29749774,  2.15294194,  5.69939517,
#         0.89167355,  1.34731944,  4.57883165,  2.80979703,  2.87254898])

# %%
y_test
# Out:
# 18     5
# 170    1
# 107    5
# 98     5
# 177    6
# 182    1
# 5      0
# 146    1
# 12     3
# 152    4
# 61     2
# 125    7
# 180    4
# 154    4
# 80     5
# 7      0
# 33     2
# 130    1
# 37     0
# 74     5
# 183    7
# 145    6
# 45     0
# 159    7
# 60     5
# 123    6
# 179    6
# 185    6
# 122    7
# 44     3
# 16     0
# 55     5
# 150    1
# 111    0
# 22     3
# 189    7
# 129    6
# 4      0
# 83     3
# 106    3
# 134    1
# 66     3
# 26     3
# 113    2
# 168    4
# 63     3
# 8      5
# 75     2
# 118    3
# 143    7
# 71     3
# 124    4
# 184    4
# 97     0
# 149    6
# 24     3
# 30     5
# 160    4
# 40     3
# 56     3
# Name: Cluster_value, dtype: int32

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
mean= mean_squared_error(y_test,pred)
mean
# Out:
# 2.927387393216696

# %%
rmse = np.sqrt(mean)
rmse
# Out:
# 1.7109609560760572

# %%
r2_score(y_test,pred)
# Out:
# 0.3880026355644538
